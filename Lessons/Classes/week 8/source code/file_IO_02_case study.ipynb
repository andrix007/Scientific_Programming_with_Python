# %% [markdown]
# # Python File Input and Output
#
# In this guide, we'll explore Python's file input and output (I/O) capabilities in detail. We'll cover various functions and methods for reading from and writing to files, understand file modes, handle text and binary data, and work with different file formats like CSV and JSON.
#
# To make the concepts more tangible, we'll use a **realistic case study**: building a simple **Contact Management System**. This system will store and retrieve contact information, demonstrating practical applications of file I/O operations.
#
# ---
#
# ## Table of Contents
#
# 1. [Introduction to File I/O](#introduction-to-file-io)
# 2. [The `open()` Function and File Modes](#the-open-function-and-file-modes)
# 3. [Reading Text Files](#reading-text-files)
# 4. [Writing Text Files](#writing-text-files)
# 5. [File Positioning with `seek()`](#file-positioning-with-seek)
# 6. [Reading and Writing Binary Files](#reading-and-writing-binary-files)
# 7. [Understanding Encoding and Unicode](#understanding-encoding-and-unicode)
# 8. [Working with CSV Files](#working-with-csv-files)
# 9. [Working with JSON Files](#working-with-json-files)
# 10. [Conclusion](#conclusion)
#
# ---
#
# ## Introduction to File I/O
#
# File I/O allows programs to interact with files stored on disk. Python provides built-in functions to perform file operations, enabling you to:
#
# - Read data from files.
# - Write data to files.
# - Manipulate file pointers.
# - Handle different file formats.
#
# ### Case Study Overview
#
# Our **Contact Management System** will:
#
# - Store contact information (name, email, phone number).
# - Read existing contacts from a file.
# - Add new contacts to the file.
# - Support different file formats (text, CSV, JSON).
#
# ---
#
# ## The `open()` Function and File Modes
#
# The `open()` function is the gateway to file operations in Python. It returns a file object, which you can use to read or write data.
#
# ### Syntax
#
# ```python
# file_object = open(file_name, mode, encoding)
# ```
#
# - **`file_name`**: The name or path of the file.
# - **`mode`**: How the file will be opened (read, write, etc.).
# - **`encoding`**: The encoding used to decode or encode the file.
#
# ### File Opening Modes
#
# | Mode | Description                                                  |
# |------|--------------------------------------------------------------|
# | `'r'`   | Open for reading (default). File must exist.                  |
# | `'w'`   | Open for writing. Creates a new file or truncates existing.   |
# | `'x'`   | Open for exclusive creation. Fails if file exists.            |
# | `'a'`   | Open for appending. Creates a new file if it doesn't exist.   |
# | `'b'`   | Binary mode.                                                  |
# | `'t'`   | Text mode (default).                                          |
# | `'+'`   | Open for updating (reading and writing).                      |
#
# ### Examples
#
# - **Read text file**: `'r'` or `'rt'`
# - **Write binary file**: `'wb'`
# - **Append to text file**: `'a'`
#
# ---
#
# ## Reading Text Files
#
# Reading text files involves opening the file in read mode and extracting its contents.
#
# ### Basic Reading

# %%
with open('contacts.txt', 'r', encoding='utf-8') as file:
    content = file.read()
    print(content)
# Out:
# Avery Dávila,avery.dávila@test.org,555-841-1026
# Avery Wilson,avery.wilson@example.com,555-535-9930
# Amelia Martinez,amelia.martinez@mail.com,555-272-8929
# Daniel Martin,daniel.martin@mail.com,555-615-1953
# Jiāng Dvořák,jiāng.dvořák@demo.net,555-210-2300
# Mark Flores,mark.flores@demo.net,555-220-2473
# José Anderson,jose.anderson@example.com,555-584-2776
# Ella Clark,ella.clark@example.com,555-291-6920
# Kevin Williams,kevin.williams@test.org,555-994-6709
# Renée Miller,renee.miller@demo.net,555-847-4764
# Åsa Dávila,asa.dávila@demo.net,555-328-5392
# Daniel Ramirez,daniel.ramirez@test.org,555-544-5066
# Léa King,lea.king@test.org,555-340-2338
# Anthony Grøn,anthony.gron@sample.co,555-296-6979
# Renée Young,renee.young@demo.net,555-634-4039
# Christopher Young,christopher.young@sample.co,555-936-4437
# Hannah Gonzalez,hannah.gonzalez@test.org,555-585-2454
# Thomas Smirnov,thomas.smirnov@test.org,555-349-6847
# Brian Garcia,brian.garcia@sample.co,555-184-1528
# Núria Gonzalez,núria.gonzalez@test.org,555-382-2712
# John White,john.white@test.org,555-858-4297
# Steven Taylor,steven.taylor@demo.net,555-409-7300
# Charlotte Garcia,charlotte.garcia@example.com,555-252-3195
# Grace King,grace.king@test.org,555-561-9701
# Paul Hernandez,paul.hernandez@sample.co,555-629-7038
# José Miller,jose.miller@demo.net,555-678-1099
# Charlotte Håkansson,charlotte.hakansson@sample.co,555-947-4427
# Christopher Thompson,christopher.thompson@demo.net,555-253-9069
# Łukasz Gonzalez,lukasz.gonzalez@mail.com,555-502-7314
# Léa Lee,lea.lee@example.com,555-105-4055
# Avery Ramirez,avery.ramirez@example.com,555-864-1034
# Sven Håkansson,sven.hakansson@demo.net,555-222-4044
# Hannah Anderson,hannah.anderson@mail.com,555-698-8671
# Thomas Martin,thomas.martin@example.com,555-963-4852
# Åsa Anderson,asa.anderson@test.org,555-284-5106
# William Moore,william.moore@mail.com,555-350-6270
# Laura Möller,laura.moller@sample.co,555-837-3052
# Sven Anderson,sven.anderson@mail.com,555-439-2940
# Sven Rodriguez,sven.rodriguez@demo.net,555-776-1154
# John Smith,john.smith@sample.co,555-632-4602
# Christopher Jackson,christopher.jackson@demo.net,555-525-9786
# Ella White,ella.white@mail.com,555-446-2076
# Grace Rodriguez,grace.rodriguez@example.com,555-644-9384
# Renée Hill,renee.hill@demo.net,555-582-2409
# Amelia Núñez,amelia.núnez@demo.net,555-802-1089
# Abigail Håkansson,abigail.hakansson@demo.net,555-266-8412
# David Harris,david.harris@sample.co,555-960-8568
# Chloe Perez,chloe.perez@sample.co,555-820-8766
# Michael Miller,michael.miller@demo.net,555-473-4964
# Steven Garcia,steven.garcia@demo.net,555-305-4539
# Thomas King,thomas.king@sample.co,555-892-9380
# Anthony Davis,anthony.davis@sample.co,555-200-3662
# José Allen,jose.allen@example.com,555-813-8165
# Charles Nguyen,charles.nguyen@demo.net,555-100-4901
# Avery Garcia,avery.garcia@sample.co,555-264-2825
# Sophia Anderson,sophia.anderson@sample.co,555-480-2272
# Mark Rodriguez,mark.rodriguez@sample.co,555-183-4945
# Evelyn Thomas,evelyn.thomas@test.org,555-959-1637
# Laura Martinez,laura.martinez@demo.net,555-530-4809
# Núria Young,núria.young@mail.com,555-720-9744
# Andrew Hill,andrew.hill@example.com,555-754-9093
# William Robinson,william.robinson@mail.com,555-460-5990
# Brian Williams,brian.williams@test.org,555-914-1434
# Chloe Perez,chloe.perez@mail.com,555-414-6911
# Avery Chen,avery.chen@test.org,555-480-3700
# Chloe White,chloe.white@sample.co,555-632-4032
# Olivia Walker,olivia.walker@mail.com,555-762-5757
# Abigail Kovačić,abigail.kovačić@demo.net,555-289-9213
# Lily Walker,lily.walker@demo.net,555-305-6273
# Andrew Gonzalez,andrew.gonzalez@test.org,555-816-2686
# Anthony Taylor,anthony.taylor@demo.net,555-137-2639
# Robert Garcia,robert.garcia@example.com,555-816-5680
# Laura Jackson,laura.jackson@demo.net,555-618-8045
# Avery Flores,avery.flores@mail.com,555-365-8160
# Christopher Wright,christopher.wright@test.org,555-272-8818
# Abigail Kovačić,abigail.kovačić@mail.com,555-780-7271
# Andrew Taylor,andrew.taylor@sample.co,555-139-3638
# John Dávila,john.dávila@demo.net,555-271-9065
# Olivia Robinson,olivia.robinson@mail.com,555-444-9967
# Mia Möller,mia.moller@example.com,555-552-6075
# Ella Flores,ella.flores@example.com,555-446-3541
# Christopher Ramirez,christopher.ramirez@sample.co,555-761-6100
# James Håkansson,james.hakansson@sample.co,555-773-8842
# Mia Thompson,mia.thompson@sample.co,555-280-1694
# Thomas Wilson,thomas.wilson@demo.net,555-402-7226
# Paul Torres,paul.torres@sample.co,555-651-1510
# Léa Garcia,lea.garcia@test.org,555-601-3087
# Amelia Gonzalez,amelia.gonzalez@mail.com,555-601-6626
# Mark Clark,mark.clark@test.org,555-507-5673
# Paul Martinez,paul.martinez@demo.net,555-569-3858
# Renée Lopez,renee.lopez@sample.co,555-325-8222
# Robert Sanchez,robert.sanchez@test.org,555-966-8982
# Robert Gonzalez,robert.gonzalez@example.com,555-255-9282
# Abigail Allen,abigail.allen@sample.co,555-108-3263
# Charles Robinson,charles.robinson@example.com,555-516-9206
# Christopher Perez,christopher.perez@demo.net,555-911-6589
# Isabella Smirnov,isabella.smirnov@mail.com,555-916-9783
# Sophia Harris,sophia.harris@demo.net,555-814-6181
# Andrew Gonzalez,andrew.gonzalez@test.org,555-298-5889
# Amelia Torres,amelia.torres@sample.co,555-579-2646
# Alice Müller,alice.muller@example.com,555-000-1234

# %% [markdown]
# - **`with`** statement ensures the file is properly closed after its suite finishes.
# - **`file.read()`** reads the entire file.
#
# ### Reading Line by Line

# %%
with open('contacts.txt', 'r', encoding='utf-8') as file:
    for line in file:
        print(line.strip())
# Out:
# Amelia Williams,amelia.williams@mail.com,555-373-3107
# Robert Scott,robert.scott@test.org,555-123-7392
# Christopher Jackson,christopher.jackson@demo.net,555-645-2499
# Zoë Nguyen,zoë.nguyen@example.com,555-162-8626
# Mia Jackson,mia.jackson@test.org,555-261-7491
# Léa Möller,lea.moller@test.org,555-570-6390
# Zoë King,zoë.king@demo.net,555-833-7962
# Emily Hernandez,emily.hernandez@example.com,555-435-8451
# Anthony Torres,anthony.torres@demo.net,555-117-2399
# Sophia Torres,sophia.torres@test.org,555-856-8973
# Ella Núñez,ella.núnez@test.org,555-153-6288
# Andrew Taylor,andrew.taylor@example.com,555-835-5004
# Avery Jackson,avery.jackson@test.org,555-461-5207
# Isabella Harris,isabella.harris@test.org,555-207-2322
# Jiāng Håkansson,jiāng.hakansson@example.com,555-734-6934
# Sophia Robinson,sophia.robinson@test.org,555-999-6716
# Hannah Scott,hannah.scott@test.org,555-629-8821
# Léa Ramirez,lea.ramirez@example.com,555-637-6401
# Sarah Garcia,sarah.garcia@demo.net,555-682-1341
# Sven Ramirez,sven.ramirez@sample.co,555-337-3042
# François Jackson,francois.jackson@demo.net,555-349-9147
# Daniel King,daniel.king@sample.co,555-767-8977
# Zoë Thompson,zoë.thompson@test.org,555-302-2448
# Robert Robinson,robert.robinson@example.com,555-600-3450
# Åsa White,asa.white@example.com,555-424-4728
# William Anderson,william.anderson@example.com,555-601-2870
# Evelyn Sanchez,evelyn.sanchez@mail.com,555-332-9089
# Léa Taylor,lea.taylor@demo.net,555-448-7707
# Åsa Smith,asa.smith@sample.co,555-697-2471
# Paul Allen,paul.allen@sample.co,555-698-1103
# Steven Nguyen,steven.nguyen@sample.co,555-970-9203
# Núria Wilson,núria.wilson@demo.net,555-408-6254
# Isabella King,isabella.king@sample.co,555-472-3224
# Jiāng Dvořák,jiāng.dvořák@example.com,555-268-1500
# Evelyn Miller,evelyn.miller@mail.com,555-741-5715
# Åsa King,asa.king@example.com,555-571-4847
# Jiāng Smirnov,jiāng.smirnov@example.com,555-726-5202
# Paul Harris,paul.harris@example.com,555-598-6534
# Amelia Johnson,amelia.johnson@example.com,555-265-9758
# Ella Walker,ella.walker@mail.com,555-915-6581
# Steven Sanchez,steven.sanchez@demo.net,555-257-6396
# Jiāng Möller,jiāng.moller@demo.net,555-315-9196
# Łukasz Dávila,lukasz.dávila@mail.com,555-243-5535
# Paul Taylor,paul.taylor@example.com,555-544-3179
# Jane Ramirez,jane.ramirez@sample.co,555-664-8179
# Jiāng Martinez,jiāng.martinez@example.com,555-874-3881
# Núria Young,núria.young@test.org,555-557-7148
# Mark Johnson,mark.johnson@demo.net,555-702-3365
# Evelyn Allen,evelyn.allen@sample.co,555-359-1462
# Åsa King,asa.king@test.org,555-383-2478
# Daniel Allen,daniel.allen@mail.com,555-656-9270
# François Thomas,francois.thomas@test.org,555-630-8688
# Núria Scott,núria.scott@test.org,555-133-9392
# Olivia Rodriguez,olivia.rodriguez@mail.com,555-797-4005
# Grace Gonzalez,grace.gonzalez@sample.co,555-464-5901
# Lily Perez,lily.perez@demo.net,555-696-5262
# Isabella Jones,isabella.jones@test.org,555-654-9584
# Anthony Dávila,anthony.dávila@test.org,555-766-9439
# Renée Dvořák,renee.dvořák@demo.net,555-954-2623
# Léa Thompson,lea.thompson@example.com,555-558-2875
# Evelyn Davis,evelyn.davis@example.com,555-960-9865
# Abigail Chen,abigail.chen@example.com,555-606-5176
# Lily Miller,lily.miller@test.org,555-375-7243
# Avery Harris,avery.harris@example.com,555-663-2660
# Olivia Moore,olivia.moore@mail.com,555-857-9606
# Isabella Nguyen,isabella.nguyen@demo.net,555-174-2491
# Thomas Garcia,thomas.garcia@mail.com,555-850-3753
# Jiāng Nguyen,jiāng.nguyen@sample.co,555-690-2957
# Chloe Wright,chloe.wright@demo.net,555-192-1147
# François Lewis,francois.lewis@example.com,555-766-3879
# Olivia Martin,olivia.martin@test.org,555-482-3242
# Lily Young,lily.young@mail.com,555-184-3224
# John Nguyen,john.nguyen@demo.net,555-236-8429
# Renée Sanchez,renee.sanchez@example.com,555-710-5199
# Chloe Garcia,chloe.garcia@example.com,555-668-8064
# Steven Kovačić,steven.kovačić@sample.co,555-785-3114
# Núria Jackson,núria.jackson@test.org,555-334-5938
# Sophia Smirnov,sophia.smirnov@test.org,555-195-9571
# Grace Scott,grace.scott@sample.co,555-357-8159
# Steven Lewis,steven.lewis@test.org,555-989-5648
# William Perez,william.perez@demo.net,555-707-8200
# Daniel Williams,daniel.williams@demo.net,555-812-5658
# Sarah Grøn,sarah.gron@example.com,555-871-8941
# Ella Moore,ella.moore@test.org,555-756-1101
# Chloe Kovačić,chloe.kovačić@mail.com,555-995-3775
# José Robinson,jose.robinson@sample.co,555-867-9227
# Charles Anderson,charles.anderson@demo.net,555-838-3976
# Olivia Jones,olivia.jones@sample.co,555-230-1282
# François Rodriguez,francois.rodriguez@sample.co,555-518-6446
# Daniel Dvořák,daniel.dvořák@demo.net,555-286-5909
# Mark King,mark.king@mail.com,555-891-6462
# Evelyn Davis,evelyn.davis@example.com,555-893-1195
# Michael Dávila,michael.dávila@sample.co,555-998-7572
# David Davis,david.davis@demo.net,555-574-1149
# Kevin Jones,kevin.jones@test.org,555-604-8041
# Charlotte Clark,charlotte.clark@example.com,555-968-1430
# Olivia White,olivia.white@mail.com,555-799-4331
# Olivia Martinez,olivia.martinez@example.com,555-872-6985
# James Brown,james.brown@sample.co,555-243-8874
# Steven Thomas,steven.thomas@sample.co,555-661-6582
# Alice Müller,alice.muller@example.com,555-000-1234

# %% [markdown]
# - **`for line in file`** iterates over each line in the file.
# - **`line.strip()`** removes leading and trailing whitespace.
#
# ### Reading Specific Number of Characters

# %%
with open('contacts.txt', 'r', encoding='utf-8') as file:
    content = file.read(100)  # Reads first 100 characters
    print(content)
# Out:
# Amelia Williams,amelia.williams@mail.com,555-373-3107
# Robert Scott,robert.scott@test.org,555-123-739

# %% [markdown]
# ### Case Study Example
#
# Let's read existing contacts from `contacts.txt`.

# %%
def read_contacts():
    contacts = []
    with open('contacts.txt', 'r', encoding='utf-8') as file:
        for line in file:
            name, email, phone = line.strip().split(',')
            contacts.append({
                'name': name,
                'email': email,
                'phone': phone
            })
    return contacts

# Usage
contacts = read_contacts()
for contact in contacts:
    print(contact)
# Out:
# {'name': 'Amelia Williams', 'email': 'amelia.williams@mail.com', 'phone': '555-373-3107'}
# {'name': 'Robert Scott', 'email': 'robert.scott@test.org', 'phone': '555-123-7392'}
# {'name': 'Christopher Jackson', 'email': 'christopher.jackson@demo.net', 'phone': '555-645-2499'}
# {'name': 'Zoë Nguyen', 'email': 'zoë.nguyen@example.com', 'phone': '555-162-8626'}
# {'name': 'Mia Jackson', 'email': 'mia.jackson@test.org', 'phone': '555-261-7491'}
# {'name': 'Léa Möller', 'email': 'lea.moller@test.org', 'phone': '555-570-6390'}
# {'name': 'Zoë King', 'email': 'zoë.king@demo.net', 'phone': '555-833-7962'}
# {'name': 'Emily Hernandez', 'email': 'emily.hernandez@example.com', 'phone': '555-435-8451'}
# {'name': 'Anthony Torres', 'email': 'anthony.torres@demo.net', 'phone': '555-117-2399'}
# {'name': 'Sophia Torres', 'email': 'sophia.torres@test.org', 'phone': '555-856-8973'}
# {'name': 'Ella Núñez', 'email': 'ella.núnez@test.org', 'phone': '555-153-6288'}
# {'name': 'Andrew Taylor', 'email': 'andrew.taylor@example.com', 'phone': '555-835-5004'}
# {'name': 'Avery Jackson', 'email': 'avery.jackson@test.org', 'phone': '555-461-5207'}
# {'name': 'Isabella Harris', 'email': 'isabella.harris@test.org', 'phone': '555-207-2322'}
# {'name': 'Jiāng Håkansson', 'email': 'jiāng.hakansson@example.com', 'phone': '555-734-6934'}
# {'name': 'Sophia Robinson', 'email': 'sophia.robinson@test.org', 'phone': '555-999-6716'}
# {'name': 'Hannah Scott', 'email': 'hannah.scott@test.org', 'phone': '555-629-8821'}
# {'name': 'Léa Ramirez', 'email': 'lea.ramirez@example.com', 'phone': '555-637-6401'}
# {'name': 'Sarah Garcia', 'email': 'sarah.garcia@demo.net', 'phone': '555-682-1341'}
# {'name': 'Sven Ramirez', 'email': 'sven.ramirez@sample.co', 'phone': '555-337-3042'}
# {'name': 'François Jackson', 'email': 'francois.jackson@demo.net', 'phone': '555-349-9147'}
# {'name': 'Daniel King', 'email': 'daniel.king@sample.co', 'phone': '555-767-8977'}
# {'name': 'Zoë Thompson', 'email': 'zoë.thompson@test.org', 'phone': '555-302-2448'}
# {'name': 'Robert Robinson', 'email': 'robert.robinson@example.com', 'phone': '555-600-3450'}
# {'name': 'Åsa White', 'email': 'asa.white@example.com', 'phone': '555-424-4728'}
# {'name': 'William Anderson', 'email': 'william.anderson@example.com', 'phone': '555-601-2870'}
# {'name': 'Evelyn Sanchez', 'email': 'evelyn.sanchez@mail.com', 'phone': '555-332-9089'}
# {'name': 'Léa Taylor', 'email': 'lea.taylor@demo.net', 'phone': '555-448-7707'}
# {'name': 'Åsa Smith', 'email': 'asa.smith@sample.co', 'phone': '555-697-2471'}
# {'name': 'Paul Allen', 'email': 'paul.allen@sample.co', 'phone': '555-698-1103'}
# {'name': 'Steven Nguyen', 'email': 'steven.nguyen@sample.co', 'phone': '555-970-9203'}
# {'name': 'Núria Wilson', 'email': 'núria.wilson@demo.net', 'phone': '555-408-6254'}
# {'name': 'Isabella King', 'email': 'isabella.king@sample.co', 'phone': '555-472-3224'}
# {'name': 'Jiāng Dvořák', 'email': 'jiāng.dvořák@example.com', 'phone': '555-268-1500'}
# {'name': 'Evelyn Miller', 'email': 'evelyn.miller@mail.com', 'phone': '555-741-5715'}
# {'name': 'Åsa King', 'email': 'asa.king@example.com', 'phone': '555-571-4847'}
# {'name': 'Jiāng Smirnov', 'email': 'jiāng.smirnov@example.com', 'phone': '555-726-5202'}
# {'name': 'Paul Harris', 'email': 'paul.harris@example.com', 'phone': '555-598-6534'}
# {'name': 'Amelia Johnson', 'email': 'amelia.johnson@example.com', 'phone': '555-265-9758'}
# {'name': 'Ella Walker', 'email': 'ella.walker@mail.com', 'phone': '555-915-6581'}
# {'name': 'Steven Sanchez', 'email': 'steven.sanchez@demo.net', 'phone': '555-257-6396'}
# {'name': 'Jiāng Möller', 'email': 'jiāng.moller@demo.net', 'phone': '555-315-9196'}
# {'name': 'Łukasz Dávila', 'email': 'lukasz.dávila@mail.com', 'phone': '555-243-5535'}
# {'name': 'Paul Taylor', 'email': 'paul.taylor@example.com', 'phone': '555-544-3179'}
# {'name': 'Jane Ramirez', 'email': 'jane.ramirez@sample.co', 'phone': '555-664-8179'}
# {'name': 'Jiāng Martinez', 'email': 'jiāng.martinez@example.com', 'phone': '555-874-3881'}
# {'name': 'Núria Young', 'email': 'núria.young@test.org', 'phone': '555-557-7148'}
# {'name': 'Mark Johnson', 'email': 'mark.johnson@demo.net', 'phone': '555-702-3365'}
# {'name': 'Evelyn Allen', 'email': 'evelyn.allen@sample.co', 'phone': '555-359-1462'}
# {'name': 'Åsa King', 'email': 'asa.king@test.org', 'phone': '555-383-2478'}
# {'name': 'Daniel Allen', 'email': 'daniel.allen@mail.com', 'phone': '555-656-9270'}
# {'name': 'François Thomas', 'email': 'francois.thomas@test.org', 'phone': '555-630-8688'}
# {'name': 'Núria Scott', 'email': 'núria.scott@test.org', 'phone': '555-133-9392'}
# {'name': 'Olivia Rodriguez', 'email': 'olivia.rodriguez@mail.com', 'phone': '555-797-4005'}
# {'name': 'Grace Gonzalez', 'email': 'grace.gonzalez@sample.co', 'phone': '555-464-5901'}
# {'name': 'Lily Perez', 'email': 'lily.perez@demo.net', 'phone': '555-696-5262'}
# {'name': 'Isabella Jones', 'email': 'isabella.jones@test.org', 'phone': '555-654-9584'}
# {'name': 'Anthony Dávila', 'email': 'anthony.dávila@test.org', 'phone': '555-766-9439'}
# {'name': 'Renée Dvořák', 'email': 'renee.dvořák@demo.net', 'phone': '555-954-2623'}
# {'name': 'Léa Thompson', 'email': 'lea.thompson@example.com', 'phone': '555-558-2875'}
# {'name': 'Evelyn Davis', 'email': 'evelyn.davis@example.com', 'phone': '555-960-9865'}
# {'name': 'Abigail Chen', 'email': 'abigail.chen@example.com', 'phone': '555-606-5176'}
# {'name': 'Lily Miller', 'email': 'lily.miller@test.org', 'phone': '555-375-7243'}
# {'name': 'Avery Harris', 'email': 'avery.harris@example.com', 'phone': '555-663-2660'}
# {'name': 'Olivia Moore', 'email': 'olivia.moore@mail.com', 'phone': '555-857-9606'}
# {'name': 'Isabella Nguyen', 'email': 'isabella.nguyen@demo.net', 'phone': '555-174-2491'}
# {'name': 'Thomas Garcia', 'email': 'thomas.garcia@mail.com', 'phone': '555-850-3753'}
# {'name': 'Jiāng Nguyen', 'email': 'jiāng.nguyen@sample.co', 'phone': '555-690-2957'}
# {'name': 'Chloe Wright', 'email': 'chloe.wright@demo.net', 'phone': '555-192-1147'}
# {'name': 'François Lewis', 'email': 'francois.lewis@example.com', 'phone': '555-766-3879'}
# {'name': 'Olivia Martin', 'email': 'olivia.martin@test.org', 'phone': '555-482-3242'}
# {'name': 'Lily Young', 'email': 'lily.young@mail.com', 'phone': '555-184-3224'}
# {'name': 'John Nguyen', 'email': 'john.nguyen@demo.net', 'phone': '555-236-8429'}
# {'name': 'Renée Sanchez', 'email': 'renee.sanchez@example.com', 'phone': '555-710-5199'}
# {'name': 'Chloe Garcia', 'email': 'chloe.garcia@example.com', 'phone': '555-668-8064'}
# {'name': 'Steven Kovačić', 'email': 'steven.kovačić@sample.co', 'phone': '555-785-3114'}
# {'name': 'Núria Jackson', 'email': 'núria.jackson@test.org', 'phone': '555-334-5938'}
# {'name': 'Sophia Smirnov', 'email': 'sophia.smirnov@test.org', 'phone': '555-195-9571'}
# {'name': 'Grace Scott', 'email': 'grace.scott@sample.co', 'phone': '555-357-8159'}
# {'name': 'Steven Lewis', 'email': 'steven.lewis@test.org', 'phone': '555-989-5648'}
# {'name': 'William Perez', 'email': 'william.perez@demo.net', 'phone': '555-707-8200'}
# {'name': 'Daniel Williams', 'email': 'daniel.williams@demo.net', 'phone': '555-812-5658'}
# {'name': 'Sarah Grøn', 'email': 'sarah.gron@example.com', 'phone': '555-871-8941'}
# {'name': 'Ella Moore', 'email': 'ella.moore@test.org', 'phone': '555-756-1101'}
# {'name': 'Chloe Kovačić', 'email': 'chloe.kovačić@mail.com', 'phone': '555-995-3775'}
# {'name': 'José Robinson', 'email': 'jose.robinson@sample.co', 'phone': '555-867-9227'}
# {'name': 'Charles Anderson', 'email': 'charles.anderson@demo.net', 'phone': '555-838-3976'}
# {'name': 'Olivia Jones', 'email': 'olivia.jones@sample.co', 'phone': '555-230-1282'}
# {'name': 'François Rodriguez', 'email': 'francois.rodriguez@sample.co', 'phone': '555-518-6446'}
# {'name': 'Daniel Dvořák', 'email': 'daniel.dvořák@demo.net', 'phone': '555-286-5909'}
# {'name': 'Mark King', 'email': 'mark.king@mail.com', 'phone': '555-891-6462'}
# {'name': 'Evelyn Davis', 'email': 'evelyn.davis@example.com', 'phone': '555-893-1195'}
# {'name': 'Michael Dávila', 'email': 'michael.dávila@sample.co', 'phone': '555-998-7572'}
# {'name': 'David Davis', 'email': 'david.davis@demo.net', 'phone': '555-574-1149'}
# {'name': 'Kevin Jones', 'email': 'kevin.jones@test.org', 'phone': '555-604-8041'}
# {'name': 'Charlotte Clark', 'email': 'charlotte.clark@example.com', 'phone': '555-968-1430'}
# {'name': 'Olivia White', 'email': 'olivia.white@mail.com', 'phone': '555-799-4331'}
# {'name': 'Olivia Martinez', 'email': 'olivia.martinez@example.com', 'phone': '555-872-6985'}
# {'name': 'James Brown', 'email': 'james.brown@sample.co', 'phone': '555-243-8874'}
# {'name': 'Steven Thomas', 'email': 'steven.thomas@sample.co', 'phone': '555-661-6582'}
# {'name': 'Alice Müller', 'email': 'alice.muller@example.com', 'phone': '555-000-1234'}

# %% [markdown]
# ---
#
# ## Writing Text Files
#
# Writing to text files allows you to store data persistently.
#
# ### Writing with `write()`

# %%
with open('contacts.txt', 'w', encoding='utf-8') as file:
    file.write('John Doe,john@example.com,555-1234\n')

# %% [markdown]
# - **`'w'` mode** truncates the file if it exists.
# - **`file.write()`** writes a string to the file.
#
# ### Appending with `append()`

# %%
with open('contacts.txt', 'a', encoding='utf-8') as file:
    file.write('Jane Smith,jane@example.com,555-5678\n')

# %% [markdown]
# - **`'a'` mode** opens the file for appending.
#
# ### Writing Multiple Lines

# %%
contacts = [
    'John Doe,john@example.com,555-1234\n',
    'Jane Smith,jane@example.com,555-5678\n'
]

with open('contacts.txt', 'w', encoding='utf-8') as file:
    file.writelines(contacts)

# %% [markdown]
# ### Case Study Example
#
# Let's write a function to add a new contact.

# %%
def add_contact(name, email, phone):
    with open('contacts.txt', 'a', encoding='utf-8') as file:
        file.write(f'{name},{email},{phone}\n')

# Usage
add_contact('Alice Brown', 'alice@example.com', '555-9012')

# %% [markdown]
# ---
#
# ## File Positioning with `seek()`
#
# The `seek()` method changes the file object's position. Useful for random access.
#
# ### Syntax

# %% [markdown]
# file.seek(offset, whence)

# %% [markdown]
# - **`offset`**: Number of bytes to move.
# - **`whence`**: Reference point (`0`=start, `1`=current position, `2`=end).
#
# ### Examples
#
# - Move to the beginning:
#
# file.seek(0)
#
# - Move to 10 bytes from the start:
#
# file.seek(10, 0)
#
# - Move to 5 bytes before the end:
#
# file.seek(-5, 2)
#
# ### Using `tell()`
#
# position = file.tell()
# print(f'Current position: {position}')
#
# ### Case Study Example
#
# Suppose we want to read the last 50 bytes of the contacts file.

# %%
with open('contacts.txt', 'rb') as file:
    file.seek(-50, 2)
    last_bytes = file.read(50)
    print(last_bytes.decode('utf-8'))
# Out:
# 555-5678
# Alice Brown,alice@example.com,555-9012

# %% [markdown]
# ---
#
# ## Reading and Writing Binary Files
#
# Binary files store data in binary format (bytes). Images, executables, and some data files use binary formats.
#
# ### Reading Binary Files

# %%
with open('image.jpg', 'rb') as file:
    data = file.read()
    print(type(data))  # Output: <class 'bytes'>
    #print(data)
# Out:
# <class 'bytes'>

# %% [markdown]
# ### Writing Binary Files

# %%
with open('copy.jpg', 'wb') as file:
    file.write(data)

# %% [markdown]
# ### Case Study Example
#
# Imagine we have a contact's profile picture to store.

# %%
def save_profile_picture(filename, data):
    with open(filename, 'wb') as file:
        file.write(data)

# Usage
with open('profile.jpg', 'rb') as original_file:
    image_data = original_file.read()

save_profile_picture('contact_profile.jpg', image_data)

# %% [markdown]
# ---
#
# ## Understanding Encoding and Unicode
#
# Text files are sequences of characters, which are represented in bytes using encodings.
#
# ### Code Points and Code Units
#
# - **Code Point**: The unique number assigned to each character in the Unicode standard.
# - **Code Unit**: The minimal bit combination that can represent a character in a given encoding.
#
# ### Common Encodings
#
# - **UTF-8**: Variable-length encoding, backwards compatible with ASCII.
# - **UTF-16**: Uses 2 or 4 bytes for each character.
# - **ASCII**: 7-bit encoding for English characters.
#
# ### Specifying Encoding
#
# Always specify the encoding when dealing with text files to avoid errors.

# %%
with open('contacts.txt', 'r', encoding='utf-8') as file:
    content = file.read()

# %% [markdown]
# ### Dealing with Unicode Characters

# %%
name = 'José Álvarez'
with open('contacts.txt', 'a', encoding='utf-8') as file:
    file.write(f'{name},jose@example.com,555-3456\n')

# %% [markdown]
# ### Case Study Example
#
# Let's read and write contacts with Unicode characters.

# %%
def add_contact(name, email, phone):
    with open('contacts.txt', 'a', encoding='utf-8') as file:
        file.write(f'{name},{email},{phone}\n')

def read_contacts():
    contacts = []
    with open('contacts.txt', 'r', encoding='utf-8') as file:
        for line in file:
            name, email, phone = line.strip().split(',')
            contacts.append({
                'name': name,
                'email': email,
                'phone': phone
            })
    return contacts

# Usage
add_contact('François Dupont', 'francois@example.fr', '555-7890')
contacts = read_contacts()
for contact in contacts:
    print(contact)
# Out:
# {'name': 'John Doe', 'email': 'john@example.com', 'phone': '555-1234'}
# {'name': 'Jane Smith', 'email': 'jane@example.com', 'phone': '555-5678'}
# {'name': 'Alice Brown', 'email': 'alice@example.com', 'phone': '555-9012'}
# {'name': 'José Álvarez', 'email': 'jose@example.com', 'phone': '555-3456'}
# {'name': 'François Dupont', 'email': 'francois@example.fr', 'phone': '555-7890'}

# %% [markdown]
# ---
#
# ## Working with CSV Files
#
# CSV files store tabular data in plain text.
#
# ### Reading CSV Files
#
# Using the built-in `csv` module:

# %%
import csv

with open('contacts.csv', 'r', encoding='utf-8', newline='') as csvfile:
    reader = csv.reader(csvfile)
    for row in reader:
        print(row)
# Out:
# ['Name', 'Email', 'Phone']
# ['Amelia Williams', 'amelia.williams@mail.com', '555-373-3107']
# ['Robert Scott', 'robert.scott@test.org', '555-123-7392']
# ['Christopher Jackson', 'christopher.jackson@demo.net', '555-645-2499']
# ['Zoë Nguyen', 'zoë.nguyen@example.com', '555-162-8626']
# ['Mia Jackson', 'mia.jackson@test.org', '555-261-7491']
# ['Léa Möller', 'lea.moller@test.org', '555-570-6390']
# ['Zoë King', 'zoë.king@demo.net', '555-833-7962']
# ['Emily Hernandez', 'emily.hernandez@example.com', '555-435-8451']
# ['Anthony Torres', 'anthony.torres@demo.net', '555-117-2399']
# ['Sophia Torres', 'sophia.torres@test.org', '555-856-8973']
# ['Ella Núñez', 'ella.núnez@test.org', '555-153-6288']
# ['Andrew Taylor', 'andrew.taylor@example.com', '555-835-5004']
# ['Avery Jackson', 'avery.jackson@test.org', '555-461-5207']
# ['Isabella Harris', 'isabella.harris@test.org', '555-207-2322']
# ['Jiāng Håkansson', 'jiāng.hakansson@example.com', '555-734-6934']
# ['Sophia Robinson', 'sophia.robinson@test.org', '555-999-6716']
# ['Hannah Scott', 'hannah.scott@test.org', '555-629-8821']
# ['Léa Ramirez', 'lea.ramirez@example.com', '555-637-6401']
# ['Sarah Garcia', 'sarah.garcia@demo.net', '555-682-1341']
# ['Sven Ramirez', 'sven.ramirez@sample.co', '555-337-3042']
# ['François Jackson', 'francois.jackson@demo.net', '555-349-9147']
# ['Daniel King', 'daniel.king@sample.co', '555-767-8977']
# ['Zoë Thompson', 'zoë.thompson@test.org', '555-302-2448']
# ['Robert Robinson', 'robert.robinson@example.com', '555-600-3450']
# ['Åsa White', 'asa.white@example.com', '555-424-4728']
# ['William Anderson', 'william.anderson@example.com', '555-601-2870']
# ['Evelyn Sanchez', 'evelyn.sanchez@mail.com', '555-332-9089']
# ['Léa Taylor', 'lea.taylor@demo.net', '555-448-7707']
# ['Åsa Smith', 'asa.smith@sample.co', '555-697-2471']
# ['Paul Allen', 'paul.allen@sample.co', '555-698-1103']
# ['Steven Nguyen', 'steven.nguyen@sample.co', '555-970-9203']
# ['Núria Wilson', 'núria.wilson@demo.net', '555-408-6254']
# ['Isabella King', 'isabella.king@sample.co', '555-472-3224']
# ['Jiāng Dvořák', 'jiāng.dvořák@example.com', '555-268-1500']
# ['Evelyn Miller', 'evelyn.miller@mail.com', '555-741-5715']
# ['Åsa King', 'asa.king@example.com', '555-571-4847']
# ['Jiāng Smirnov', 'jiāng.smirnov@example.com', '555-726-5202']
# ['Paul Harris', 'paul.harris@example.com', '555-598-6534']
# ['Amelia Johnson', 'amelia.johnson@example.com', '555-265-9758']
# ['Ella Walker', 'ella.walker@mail.com', '555-915-6581']
# ['Steven Sanchez', 'steven.sanchez@demo.net', '555-257-6396']
# ['Jiāng Möller', 'jiāng.moller@demo.net', '555-315-9196']
# ['Łukasz Dávila', 'lukasz.dávila@mail.com', '555-243-5535']
# ['Paul Taylor', 'paul.taylor@example.com', '555-544-3179']
# ['Jane Ramirez', 'jane.ramirez@sample.co', '555-664-8179']
# ['Jiāng Martinez', 'jiāng.martinez@example.com', '555-874-3881']
# ['Núria Young', 'núria.young@test.org', '555-557-7148']
# ['Mark Johnson', 'mark.johnson@demo.net', '555-702-3365']
# ['Evelyn Allen', 'evelyn.allen@sample.co', '555-359-1462']
# ['Åsa King', 'asa.king@test.org', '555-383-2478']
# ['Daniel Allen', 'daniel.allen@mail.com', '555-656-9270']
# ['François Thomas', 'francois.thomas@test.org', '555-630-8688']
# ['Núria Scott', 'núria.scott@test.org', '555-133-9392']
# ['Olivia Rodriguez', 'olivia.rodriguez@mail.com', '555-797-4005']
# ['Grace Gonzalez', 'grace.gonzalez@sample.co', '555-464-5901']
# ['Lily Perez', 'lily.perez@demo.net', '555-696-5262']
# ['Isabella Jones', 'isabella.jones@test.org', '555-654-9584']
# ['Anthony Dávila', 'anthony.dávila@test.org', '555-766-9439']
# ['Renée Dvořák', 'renee.dvořák@demo.net', '555-954-2623']
# ['Léa Thompson', 'lea.thompson@example.com', '555-558-2875']
# ['Evelyn Davis', 'evelyn.davis@example.com', '555-960-9865']
# ['Abigail Chen', 'abigail.chen@example.com', '555-606-5176']
# ['Lily Miller', 'lily.miller@test.org', '555-375-7243']
# ['Avery Harris', 'avery.harris@example.com', '555-663-2660']
# ['Olivia Moore', 'olivia.moore@mail.com', '555-857-9606']
# ['Isabella Nguyen', 'isabella.nguyen@demo.net', '555-174-2491']
# ['Thomas Garcia', 'thomas.garcia@mail.com', '555-850-3753']
# ['Jiāng Nguyen', 'jiāng.nguyen@sample.co', '555-690-2957']
# ['Chloe Wright', 'chloe.wright@demo.net', '555-192-1147']
# ['François Lewis', 'francois.lewis@example.com', '555-766-3879']
# ['Olivia Martin', 'olivia.martin@test.org', '555-482-3242']
# ['Lily Young', 'lily.young@mail.com', '555-184-3224']
# ['John Nguyen', 'john.nguyen@demo.net', '555-236-8429']
# ['Renée Sanchez', 'renee.sanchez@example.com', '555-710-5199']
# ['Chloe Garcia', 'chloe.garcia@example.com', '555-668-8064']
# ['Steven Kovačić', 'steven.kovačić@sample.co', '555-785-3114']
# ['Núria Jackson', 'núria.jackson@test.org', '555-334-5938']
# ['Sophia Smirnov', 'sophia.smirnov@test.org', '555-195-9571']
# ['Grace Scott', 'grace.scott@sample.co', '555-357-8159']
# ['Steven Lewis', 'steven.lewis@test.org', '555-989-5648']
# ['William Perez', 'william.perez@demo.net', '555-707-8200']
# ['Daniel Williams', 'daniel.williams@demo.net', '555-812-5658']
# ['Sarah Grøn', 'sarah.gron@example.com', '555-871-8941']
# ['Ella Moore', 'ella.moore@test.org', '555-756-1101']
# ['Chloe Kovačić', 'chloe.kovačić@mail.com', '555-995-3775']
# ['José Robinson', 'jose.robinson@sample.co', '555-867-9227']
# ['Charles Anderson', 'charles.anderson@demo.net', '555-838-3976']
# ['Olivia Jones', 'olivia.jones@sample.co', '555-230-1282']
# ['François Rodriguez', 'francois.rodriguez@sample.co', '555-518-6446']
# ['Daniel Dvořák', 'daniel.dvořák@demo.net', '555-286-5909']
# ['Mark King', 'mark.king@mail.com', '555-891-6462']
# ['Evelyn Davis', 'evelyn.davis@example.com', '555-893-1195']
# ['Michael Dávila', 'michael.dávila@sample.co', '555-998-7572']
# ['David Davis', 'david.davis@demo.net', '555-574-1149']
# ['Kevin Jones', 'kevin.jones@test.org', '555-604-8041']
# ['Charlotte Clark', 'charlotte.clark@example.com', '555-968-1430']
# ['Olivia White', 'olivia.white@mail.com', '555-799-4331']
# ['Olivia Martinez', 'olivia.martinez@example.com', '555-872-6985']
# ['James Brown', 'james.brown@sample.co', '555-243-8874']
# ['Steven Thomas', 'steven.thomas@sample.co', '555-661-6582']
# ['Alice Müller', 'alice.muller@example.com', '555-000-1234']

# %% [markdown]
# ### Handling Headers

# %%
with open('contacts.csv', 'r', encoding='utf-8', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        print(row['Name'], row['Email'], row['Phone'])
# Out:
# Amelia Williams amelia.williams@mail.com 555-373-3107
# Robert Scott robert.scott@test.org 555-123-7392
# Christopher Jackson christopher.jackson@demo.net 555-645-2499
# Zoë Nguyen zoë.nguyen@example.com 555-162-8626
# Mia Jackson mia.jackson@test.org 555-261-7491
# Léa Möller lea.moller@test.org 555-570-6390
# Zoë King zoë.king@demo.net 555-833-7962
# Emily Hernandez emily.hernandez@example.com 555-435-8451
# Anthony Torres anthony.torres@demo.net 555-117-2399
# Sophia Torres sophia.torres@test.org 555-856-8973
# Ella Núñez ella.núnez@test.org 555-153-6288
# Andrew Taylor andrew.taylor@example.com 555-835-5004
# Avery Jackson avery.jackson@test.org 555-461-5207
# Isabella Harris isabella.harris@test.org 555-207-2322
# Jiāng Håkansson jiāng.hakansson@example.com 555-734-6934
# Sophia Robinson sophia.robinson@test.org 555-999-6716
# Hannah Scott hannah.scott@test.org 555-629-8821
# Léa Ramirez lea.ramirez@example.com 555-637-6401
# Sarah Garcia sarah.garcia@demo.net 555-682-1341
# Sven Ramirez sven.ramirez@sample.co 555-337-3042
# François Jackson francois.jackson@demo.net 555-349-9147
# Daniel King daniel.king@sample.co 555-767-8977
# Zoë Thompson zoë.thompson@test.org 555-302-2448
# Robert Robinson robert.robinson@example.com 555-600-3450
# Åsa White asa.white@example.com 555-424-4728
# William Anderson william.anderson@example.com 555-601-2870
# Evelyn Sanchez evelyn.sanchez@mail.com 555-332-9089
# Léa Taylor lea.taylor@demo.net 555-448-7707
# Åsa Smith asa.smith@sample.co 555-697-2471
# Paul Allen paul.allen@sample.co 555-698-1103
# Steven Nguyen steven.nguyen@sample.co 555-970-9203
# Núria Wilson núria.wilson@demo.net 555-408-6254
# Isabella King isabella.king@sample.co 555-472-3224
# Jiāng Dvořák jiāng.dvořák@example.com 555-268-1500
# Evelyn Miller evelyn.miller@mail.com 555-741-5715
# Åsa King asa.king@example.com 555-571-4847
# Jiāng Smirnov jiāng.smirnov@example.com 555-726-5202
# Paul Harris paul.harris@example.com 555-598-6534
# Amelia Johnson amelia.johnson@example.com 555-265-9758
# Ella Walker ella.walker@mail.com 555-915-6581
# Steven Sanchez steven.sanchez@demo.net 555-257-6396
# Jiāng Möller jiāng.moller@demo.net 555-315-9196
# Łukasz Dávila lukasz.dávila@mail.com 555-243-5535
# Paul Taylor paul.taylor@example.com 555-544-3179
# Jane Ramirez jane.ramirez@sample.co 555-664-8179
# Jiāng Martinez jiāng.martinez@example.com 555-874-3881
# Núria Young núria.young@test.org 555-557-7148
# Mark Johnson mark.johnson@demo.net 555-702-3365
# Evelyn Allen evelyn.allen@sample.co 555-359-1462
# Åsa King asa.king@test.org 555-383-2478
# Daniel Allen daniel.allen@mail.com 555-656-9270
# François Thomas francois.thomas@test.org 555-630-8688
# Núria Scott núria.scott@test.org 555-133-9392
# Olivia Rodriguez olivia.rodriguez@mail.com 555-797-4005
# Grace Gonzalez grace.gonzalez@sample.co 555-464-5901
# Lily Perez lily.perez@demo.net 555-696-5262
# Isabella Jones isabella.jones@test.org 555-654-9584
# Anthony Dávila anthony.dávila@test.org 555-766-9439
# Renée Dvořák renee.dvořák@demo.net 555-954-2623
# Léa Thompson lea.thompson@example.com 555-558-2875
# Evelyn Davis evelyn.davis@example.com 555-960-9865
# Abigail Chen abigail.chen@example.com 555-606-5176
# Lily Miller lily.miller@test.org 555-375-7243
# Avery Harris avery.harris@example.com 555-663-2660
# Olivia Moore olivia.moore@mail.com 555-857-9606
# Isabella Nguyen isabella.nguyen@demo.net 555-174-2491
# Thomas Garcia thomas.garcia@mail.com 555-850-3753
# Jiāng Nguyen jiāng.nguyen@sample.co 555-690-2957
# Chloe Wright chloe.wright@demo.net 555-192-1147
# François Lewis francois.lewis@example.com 555-766-3879
# Olivia Martin olivia.martin@test.org 555-482-3242
# Lily Young lily.young@mail.com 555-184-3224
# John Nguyen john.nguyen@demo.net 555-236-8429
# Renée Sanchez renee.sanchez@example.com 555-710-5199
# Chloe Garcia chloe.garcia@example.com 555-668-8064
# Steven Kovačić steven.kovačić@sample.co 555-785-3114
# Núria Jackson núria.jackson@test.org 555-334-5938
# Sophia Smirnov sophia.smirnov@test.org 555-195-9571
# Grace Scott grace.scott@sample.co 555-357-8159
# Steven Lewis steven.lewis@test.org 555-989-5648
# William Perez william.perez@demo.net 555-707-8200
# Daniel Williams daniel.williams@demo.net 555-812-5658
# Sarah Grøn sarah.gron@example.com 555-871-8941
# Ella Moore ella.moore@test.org 555-756-1101
# Chloe Kovačić chloe.kovačić@mail.com 555-995-3775
# José Robinson jose.robinson@sample.co 555-867-9227
# Charles Anderson charles.anderson@demo.net 555-838-3976
# Olivia Jones olivia.jones@sample.co 555-230-1282
# François Rodriguez francois.rodriguez@sample.co 555-518-6446
# Daniel Dvořák daniel.dvořák@demo.net 555-286-5909
# Mark King mark.king@mail.com 555-891-6462
# Evelyn Davis evelyn.davis@example.com 555-893-1195
# Michael Dávila michael.dávila@sample.co 555-998-7572
# David Davis david.davis@demo.net 555-574-1149
# Kevin Jones kevin.jones@test.org 555-604-8041
# Charlotte Clark charlotte.clark@example.com 555-968-1430
# Olivia White olivia.white@mail.com 555-799-4331
# Olivia Martinez olivia.martinez@example.com 555-872-6985
# James Brown james.brown@sample.co 555-243-8874
# Steven Thomas steven.thomas@sample.co 555-661-6582
# Alice Müller alice.muller@example.com 555-000-1234

# %% [markdown]
# ### Writing CSV Files

# %%
import csv

contacts = [
    {'Name': 'John Doe', 'Email': 'john@example.com', 'Phone': '555-1234'},
    {'Name': 'Jane Smith', 'Email': 'jane@example.com', 'Phone': '555-5678'}
]

with open('contacts.csv', 'w', encoding='utf-8', newline='') as csvfile:
    fieldnames = ['Name', 'Email', 'Phone']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader()
    for contact in contacts:
        writer.writerow(contact)

# %% [markdown]
# ### Case Study Example
#
# Let's convert our contacts to CSV format.

# %%
def save_contacts_to_csv(contacts):
    with open('contacts.csv', 'w', encoding='utf-8', newline='') as csvfile:
        fieldnames = ['name', 'email', 'phone']
        #fieldnames = ['Name', 'Email', 'Phone'] # gives error on capitalized first letter
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

        writer.writeheader()
        for contact in contacts:
            writer.writerow(contact)

# Usage
contacts = read_contacts()
save_contacts_to_csv(contacts)

# %% [markdown]
# ---
#
# ## Working with JSON Files
#
# JSON files store data in a structured, hierarchical format, ideal for complex data.
#
# ### Reading JSON Files

# %%
import json

with open('contacts.json', 'r', encoding='utf-8') as jsonfile:
    data = json.load(jsonfile)
    print(data)
# Out:
# [{'name': 'Amelia Williams', 'email': 'amelia.williams@mail.com', 'phone': '555-373-3107'}, {'name': 'Robert Scott', 'email': 'robert.scott@test.org', 'phone': '555-123-7392'}, {'name': 'Christopher Jackson', 'email': 'christopher.jackson@demo.net', 'phone': '555-645-2499'}, {'name': 'Zoë Nguyen', 'email': 'zoë.nguyen@example.com', 'phone': '555-162-8626'}, {'name': 'Mia Jackson', 'email': 'mia.jackson@test.org', 'phone': '555-261-7491'}, {'name': 'Léa Möller', 'email': 'lea.moller@test.org', 'phone': '555-570-6390'}, {'name': 'Zoë King', 'email': 'zoë.king@demo.net', 'phone': '555-833-7962'}, {'name': 'Emily Hernandez', 'email': 'emily.hernandez@example.com', 'phone': '555-435-8451'}, {'name': 'Anthony Torres', 'email': 'anthony.torres@demo.net', 'phone': '555-117-2399'}, {'name': 'Sophia Torres', 'email': 'sophia.torres@test.org', 'phone': '555-856-8973'}, {'name': 'Ella Núñez', 'email': 'ella.núnez@test.org', 'phone': '555-153-6288'}, {'name': 'Andrew Taylor', 'email': 'andrew.taylor@example.com', 'phone': '555-835-5004'}, {'name': 'Avery Jackson', 'email': 'avery.jackson@test.org', 'phone': '555-461-5207'}, {'name': 'Isabella Harris', 'email': 'isabella.harris@test.org', 'phone': '555-207-2322'}, {'name': 'Jiāng Håkansson', 'email': 'jiāng.hakansson@example.com', 'phone': '555-734-6934'}, {'name': 'Sophia Robinson', 'email': 'sophia.robinson@test.org', 'phone': '555-999-6716'}, {'name': 'Hannah Scott', 'email': 'hannah.scott@test.org', 'phone': '555-629-8821'}, {'name': 'Léa Ramirez', 'email': 'lea.ramirez@example.com', 'phone': '555-637-6401'}, {'name': 'Sarah Garcia', 'email': 'sarah.garcia@demo.net', 'phone': '555-682-1341'}, {'name': 'Sven Ramirez', 'email': 'sven.ramirez@sample.co', 'phone': '555-337-3042'}, {'name': 'François Jackson', 'email': 'francois.jackson@demo.net', 'phone': '555-349-9147'}, {'name': 'Daniel King', 'email': 'daniel.king@sample.co', 'phone': '555-767-8977'}, {'name': 'Zoë Thompson', 'email': 'zoë.thompson@test.org', 'phone': '555-302-2448'}, {'name': 'Robert Robinson', 'email': 'robert.robinson@example.com', 'phone': '555-600-3450'}, {'name': 'Åsa White', 'email': 'asa.white@example.com', 'phone': '555-424-4728'}, {'name': 'William Anderson', 'email': 'william.anderson@example.com', 'phone': '555-601-2870'}, {'name': 'Evelyn Sanchez', 'email': 'evelyn.sanchez@mail.com', 'phone': '555-332-9089'}, {'name': 'Léa Taylor', 'email': 'lea.taylor@demo.net', 'phone': '555-448-7707'}, {'name': 'Åsa Smith', 'email': 'asa.smith@sample.co', 'phone': '555-697-2471'}, {'name': 'Paul Allen', 'email': 'paul.allen@sample.co', 'phone': '555-698-1103'}, {'name': 'Steven Nguyen', 'email': 'steven.nguyen@sample.co', 'phone': '555-970-9203'}, {'name': 'Núria Wilson', 'email': 'núria.wilson@demo.net', 'phone': '555-408-6254'}, {'name': 'Isabella King', 'email': 'isabella.king@sample.co', 'phone': '555-472-3224'}, {'name': 'Jiāng Dvořák', 'email': 'jiāng.dvořák@example.com', 'phone': '555-268-1500'}, {'name': 'Evelyn Miller', 'email': 'evelyn.miller@mail.com', 'phone': '555-741-5715'}, {'name': 'Åsa King', 'email': 'asa.king@example.com', 'phone': '555-571-4847'}, {'name': 'Jiāng Smirnov', 'email': 'jiāng.smirnov@example.com', 'phone': '555-726-5202'}, {'name': 'Paul Harris', 'email': 'paul.harris@example.com', 'phone': '555-598-6534'}, {'name': 'Amelia Johnson', 'email': 'amelia.johnson@example.com', 'phone': '555-265-9758'}, {'name': 'Ella Walker', 'email': 'ella.walker@mail.com', 'phone': '555-915-6581'}, {'name': 'Steven Sanchez', 'email': 'steven.sanchez@demo.net', 'phone': '555-257-6396'}, {'name': 'Jiāng Möller', 'email': 'jiāng.moller@demo.net', 'phone': '555-315-9196'}, {'name': 'Łukasz Dávila', 'email': 'lukasz.dávila@mail.com', 'phone': '555-243-5535'}, {'name': 'Paul Taylor', 'email': 'paul.taylor@example.com', 'phone': '555-544-3179'}, {'name': 'Jane Ramirez', 'email': 'jane.ramirez@sample.co', 'phone': '555-664-8179'}, {'name': 'Jiāng Martinez', 'email': 'jiāng.martinez@example.com', 'phone': '555-874-388 ...

# %% [markdown]
# ### Writing JSON Files

# %%
import json

contacts = [
    {'name': 'John Doe', 'email': 'john@example.com', 'phone': '555-1234'},
    {'name': 'Jane Smith', 'email': 'jane@example.com', 'phone': '555-5678'}
]

with open('contacts.json', 'w', encoding='utf-8') as jsonfile:
    json.dump(contacts, jsonfile, ensure_ascii=False, indent=4)

# %% [markdown]
# - **`ensure_ascii=False`** allows for Unicode characters.
# - **`indent=4`** makes the JSON file human-readable.
#
# ### Case Study Example
#
# Convert contacts to JSON format.

# %%
def save_contacts_to_json(contacts):
    with open('contacts.json', 'w', encoding='utf-8') as jsonfile:
        json.dump(contacts, jsonfile, ensure_ascii=False, indent=4)

# Usage
contacts = read_contacts()
save_contacts_to_json(contacts)

# %% [markdown]
# ---
#
# ## Conclusion
#
# In this guide, we've covered:
#
# - **Reading and writing text files**: Essential for basic data storage.
# - **File manipulation functions**: `open()`, `read()`, `write()`, `close()`, `seek()`.
# - **File opening modes**: Understanding how to control file access.
# - **File positioning**: Using `seek()` to navigate files.
# - **Binary file operations**: Handling non-text data.
# - **Encoding and Unicode**: Ensuring proper handling of text data.
# - **Working with CSV and JSON**: Managing structured data formats.
#
# By applying these concepts to our **Contact Management System**, we've demonstrated practical uses of file I/O in Python. With these skills, you can manage data effectively in your own projects.
#
# ---
#
# **Next Steps**
#
# - Experiment with other file formats (e.g., XML, Excel).
# - Handle exceptions using `try` and `except` blocks (to be covered in week-11.
# - Explore third-party libraries for advanced file operations.
#
# ---
